# %%
# Import Python Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
car_crash_df=pd.read_csv("Crash_Reporting_-_Drivers_Data.csv")

# %%
car_crash_df.head(5)
# Out:
#   Report Number Local Case Number                Agency Name  \
# 0    DD5620004G         190046109  Rockville Police Departme
# 1   MCP29620057         200023865   Montgomery County Police
# 2   MCP2651004P         210035267   Montgomery County Police
# 3   MCP3050004K         200016465   Montgomery County Police
# 4   MCP2641001J         200016526   Montgomery County Police
#
#         ACRS Report Type         Crash Date/Time Route Type     Road Name  \
# 0  Property Damage Crash  09/26/2019 07:20:00 AM        NaN           NaN
# 1  Property Damage Crash  06/18/2020 02:00:00 AM     County  DAIRYMAID DR
# 2  Property Damage Crash        09-08-2021 12:30        NaN           NaN
# 3  Property Damage Crash  04/19/2020 03:39:00 PM     County    RUSSETT RD
# 4           Injury Crash  04/20/2020 09:15:00 AM     County   ARCHDALE RD
#
#   Cross-Street Type  Cross-Street Name                Off-Road Description  \
# 0               NaN                NaN                         PARKING LOT
# 1            County            METZ DR                                 NaN
# 2               NaN                NaN  PARKING LOT OF 10109 COLESVILLE RD
# 3            County         ARCTIC AVE                                 NaN
# 4            County  GUNNERS BRANCH RD                                 NaN
#
#    ... Speed Limit Driverless Vehicle Parked Vehicle Vehicle Year  \
# 0  ...          15                 No             No         2017
# 1  ...          35                 No             No         2020
# 2  ...           0                 No             No         2010
# 3  ...          25                 No             No         2004
# 4  ...          25                 No             No         2006
#
#   Vehicle Make  Vehicle Model Equipment Problems   Latitude  Longitude  \
# 0       THOMAS            BUS          NO MISUSE  39.103518 -77.157669
# 1          UNK            UNK            UNKNOWN  39.154847 -77.271245
# 2       TOYOTA            SUV            UNKNOWN  39.020303 -77.011436
# 3        DODGE  GRAND CARAVAN          NO MISUSE  39.080062 -77.097845
# 4        HONDA           CR-V            UNKNOWN  39.175230 -77.241090
#
#                       Location
# 0  (39.10351817, -77.15766933)
# 1    (39.15484667, -77.271245)
# 2  (39.02030267, -77.01143583)
# 3    (39.08006167, -77.097845)
# 4        (39.17523, -77.24109)
#
# [5 rows x 43 columns]

# %%
print('There are {} rows and {} columns in our dataset'.format(car_crash_df.shape[0],car_crash_df.shape[1]))
# Out:
# There are 157840 rows and 43 columns in our dataset

# %%
car_crash_df.describe()
# Out:
#          Speed Limit   Vehicle Year       Latitude      Longitude
# count  157840.000000  157840.000000  157840.000000  157840.000000
# mean       32.632444    1966.609782      39.082917     -77.112194
# std        11.062877     339.075184       0.072129       0.098758
# min         0.000000       0.000000      37.720000     -79.486000
# 25%        25.000000    2005.000000      39.024185     -77.188762
# 50%        35.000000    2011.000000      39.074793     -77.105150
# 75%        40.000000    2015.000000      39.139104     -77.039530
# max        70.000000    9999.000000      39.990414     -75.527708

# %%
car_crash_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157840 entries, 0 to 157839
# Data columns (total 43 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Report Number                   157840 non-null  object
#  1   Local Case Number               157840 non-null  object
#  2   Agency Name                     157840 non-null  object
#  3   ACRS Report Type                157840 non-null  object
#  4   Crash Date/Time                 157840 non-null  object
#  5   Route Type                      142357 non-null  object
#  6   Road Name                       143215 non-null  object
#  7   Cross-Street Type               142333 non-null  object
#  8   Cross-Street Name               143207 non-null  object
#  9   Off-Road Description            14623 non-null   object
#  10  Municipality                    17541 non-null   object
#  11  Related Non-Motorist            4969 non-null    object
#  12  Collision Type                  157313 non-null  object
#  13  Weather                         145458 non-null  object
#  14  Surface Condition               139317 non-null  object
#  15  Light                           156531 non-null  object
#  16  Traffic Control                 134092 non-null  object
#  17  Driver Substance Abuse          129154 non-null  object
#  18  Non-Motorist Substance Abuse    3939 non-null    object
#  19  Person ID                       157840 non-null  object
#  20  Driver At Fault                 157840 non-null  object
#  21  Injury Severity                 157840 non-null  object
#  22  Circumstance                    29166 non-null   object
#  23  Driver Distracted By            157840 non-null  object
#  24  Drivers License State           149075 non-null  object
#  25  Vehicle ID                      157840 non-null  object
#  26  Vehicle Damage Extent           157561 non-null  object
#  27  Vehicle First Impact Location   157684 non-null  object
#  28  Vehicle Second Impact Location  157584 non-null  object
#  29  Vehicle Body Type               155422 non-null  object
#  30  Vehicle Movement                157506 non-null  object
#  31  Vehicle Continuing Dir          155382 non-null  object
#  32  Vehicle Going Dir               155382 non-null  object
#  33  Speed Limit                     157840 non-null  int64
#  34  Driverless Vehicle              157840 non-null  object
#  35  Parked Vehicle                  157840 non-null  object
#  36  Vehicle Year                    157840 non-null  int64
#  37  Vehicle Make                    157818 non-null  object
#  38  Vehicle Model                   157780 non-null  object
#  39  Equipment Problems              125815 non-null  object
#  40  Latitude                        157840 non-null  float64
#  41  Longitude                       157840 non-null  float64
#  42  Location                        157840 non-null  object
# dtypes: float64(2), int64(2), object(39)
# memory usage: 51.8+ MB

# %%
car_crash_df.isnull().sum()
# Out:
# Report Number                          0
# Local Case Number                      0
# Agency Name                            0
# ACRS Report Type                       0
# Crash Date/Time                        0
# Route Type                         15483
# Road Name                          14625
# Cross-Street Type                  15507
# Cross-Street Name                  14633
# Off-Road Description              143217
# Municipality                      140299
# Related Non-Motorist              152871
# Collision Type                       527
# Weather                            12382
# Surface Condition                  18523
# Light                               1309
# Traffic Control                    23748
# Driver Substance Abuse             28686
# Non-Motorist Substance Abuse      153901
# Person ID                              0
# Driver At Fault                        0
# Injury Severity                        0
# Circumstance                      128674
# Driver Distracted By                   0
# Drivers License State               8765
# Vehicle ID                             0
# Vehicle Damage Extent                279
# Vehicle First Impact Location        156
# Vehicle Second Impact Location       256
# Vehicle Body Type                   2418
# Vehicle Movement                     334
# Vehicle Continuing Dir              2458
# Vehicle Going Dir                   2458
# Speed Limit                            0
# Driverless Vehicle                     0
# Parked Vehicle                         0
# Vehicle Year                           0
# Vehicle Make                          22
# Vehicle Model                         60
# Equipment Problems                 32025
# Latitude                               0
# Longitude                              0
# Location                               0
# dtype: int64

# %%
#droping columns
dropped_df=car_crash_df.drop(['Report Number','Off-Road Description','Municipality','Related Non-Motorist','Non-Motorist Substance Abuse','Circumstance'],axis=1)
dropped_df
# Out:
#        Local Case Number                Agency Name       ACRS Report Type  \
# 0              190046109  Rockville Police Departme  Property Damage Crash
# 1              200023865   Montgomery County Police  Property Damage Crash
# 2              210035267   Montgomery County Police  Property Damage Crash
# 3              200016465   Montgomery County Police  Property Damage Crash
# 4              200016526   Montgomery County Police           Injury Crash
# ...                  ...                        ...                    ...
# 157835         230016438   Montgomery County Police           Injury Crash
# 157836         230016731   Montgomery County Police           Injury Crash
# 157837         230016769   Montgomery County Police  Property Damage Crash
# 157838         230017164   Montgomery County Police           Injury Crash
# 157839         230016332   Montgomery County Police           Injury Crash
#
#                Crash Date/Time        Route Type       Road Name  \
# 0       09/26/2019 07:20:00 AM               NaN             NaN
# 1       06/18/2020 02:00:00 AM            County    DAIRYMAID DR
# 2             09-08-2021 12:30               NaN             NaN
# 3       04/19/2020 03:39:00 PM            County      RUSSETT RD
# 4       04/20/2020 09:15:00 AM            County     ARCHDALE RD
# ...                        ...               ...             ...
# 157835        04-06-2023 16:24  Maryland (State)      CLOPPER RD
# 157836        04-08-2023 05:10            County  SHADY GROVE RD
# 157837        04-08-2023 11:50  Maryland (State)     GEORGIA AVE
# 157838        04-10-2023 22:10  Maryland (State)    GOLDSBORO RD
# 157839        04-05-2023 18:15        US (State)   COLUMBIA PIKE
#
#        Cross-Street Type      Cross-Street Name             Collision Type  \
# 0                    NaN                    NaN             SINGLE VEHICLE
# 1                 County                METZ DR                      OTHER
# 2                    NaN                    NaN                      OTHER
# 3                 County             ARCTIC AVE                      OTHER
# 4                 County      GUNNERS BRANCH RD                      OTHER
# ...                  ...                    ...                        ...
# 157835            County            CINNAMON DR     ANGLE MEETS RIGHT TURN
# 157836  Maryland (State)      MUNCASTER MILL RD    STRAIGHT MOVEMENT ANGLE
# 157837  Maryland (State)  OLNEY SANDY SPRING RD          SAME DIR REAR END
# 157838  Maryland (State)      MASSACHUSETTS AVE                    HEAD ON
# 157839            County             STEWART LA  SAME DIRECTION RIGHT TURN
#
#        Weather  ... Speed Limit Driverless Vehicle Parked Vehicle  \
# 0        CLEAR  ...          15                 No             No
# 1       CLOUDY  ...          35                 No             No
# 2        CLEAR  ...           0                 No             No
# 3        CLEAR  ...          25                 No             No
# 4       CLOUDY  ...          25                 No             No
# ...        ...  ...         ...                ...            ...
# 157835   CLEAR  ...          30                 No             No
# 157836   CLEAR  ...          40                 No             No
# 157837   CLEAR  ...          30                 No             No
# 157838   CLEAR  ...          25                 No             No
# 157839   CLEAR  ...          50                 No             No
#
#        Vehicle Year Vehicle Make  Vehicle Model Equipment Problems   Latitude  \
# 0              2017       THOMAS            BUS          NO MISUSE  39.103518
# 1              2020          UNK            UNK            UNKNOWN  39.154847
# 2              2010       TOYOTA            SUV            UNKNOWN  39.020303
# 3              2004        DODGE  GRAND CARAVAN          NO MISUSE  39.080062
# 4              2006        HONDA           CR-V            UNKNOWN  39.175230
# ...             ...          ...            ...                ...        ...
# 157835         2008         TOYT          CAMRY          NO MISUSE  39.156162
# 157836         2019        HONDA          CIVIC          NO MISUSE  39.148709
# 157837         2020    CHEVROLET        EQUINOX          NO MISUSE  39.152575
# 157838         2017      HYUNDAI         SONATA                NaN  38.970008
# 157839            0      UNKNOWN        UNKNOWN            UNKNOWN  39.049011
#
#         Longitude                     Location
# 0      -77.157669  (39.10351817, -77.15766933)
# 1      -77.271245    (39.15484667, -77.271245)
# 2      -77.011436  (39.02030267, -77.01143583)
# 3      -77.097845    (39.08006167, -77.097845)
# 4      -77.241090        (39.17523, -77.24109)
# ...           ...                          ...
# 157835 -77.264571  (39.15616222, -77.26457057)
# 157836 -77.147145  (39.14870889, -77.14714516)
# 157837 -77.066550       (39.152575, -77.06655)
# 157838 -77.131061    (38.97000767, -77.131061)
# 157839 -76.982739  (39.04901083, -76.98273917)
#
# [157840 rows x 37 columns]

# %%
dropped_df.isnull().sum()
# Out:
# Local Case Number                     0
# Agency Name                           0
# ACRS Report Type                      0
# Crash Date/Time                       0
# Route Type                        15483
# Road Name                         14625
# Cross-Street Type                 15507
# Cross-Street Name                 14633
# Collision Type                      527
# Weather                           12382
# Surface Condition                 18523
# Light                              1309
# Traffic Control                   23748
# Driver Substance Abuse            28686
# Person ID                             0
# Driver At Fault                       0
# Injury Severity                       0
# Driver Distracted By                  0
# Drivers License State              8765
# Vehicle ID                            0
# Vehicle Damage Extent               279
# Vehicle First Impact Location       156
# Vehicle Second Impact Location      256
# Vehicle Body Type                  2418
# Vehicle Movement                    334
# Vehicle Continuing Dir             2458
# Vehicle Going Dir                  2458
# Speed Limit                           0
# Driverless Vehicle                    0
# Parked Vehicle                        0
# Vehicle Year                          0
# Vehicle Make                         22
# Vehicle Model                        60
# Equipment Problems                32025
# Latitude                              0
# Longitude                             0
# Location                              0
# dtype: int64

# %%
dropna_df=dropped_df.dropna()
dropna_df
# Out:
#        Local Case Number                Agency Name       ACRS Report Type  \
# 3              200016465   Montgomery County Police  Property Damage Crash
# 4              200016526   Montgomery County Police           Injury Crash
# 6              200016622  Rockville Police Departme  Property Damage Crash
# 7              200013792   Montgomery County Police  Property Damage Crash
# 13             200016382   Montgomery County Police           Injury Crash
# ...                  ...                        ...                    ...
# 157832         230015879   Montgomery County Police           Injury Crash
# 157834         230016505  Rockville Police Departme           Injury Crash
# 157835         230016438   Montgomery County Police           Injury Crash
# 157836         230016731   Montgomery County Police           Injury Crash
# 157837         230016769   Montgomery County Police  Property Damage Crash
#
#                Crash Date/Time        Route Type              Road Name  \
# 3       04/19/2020 03:39:00 PM            County             RUSSETT RD
# 4       04/20/2020 09:15:00 AM            County            ARCHDALE RD
# 6       04/21/2020 06:45:00 AM      Municipality           WOOTTON PKWY
# 7       03/24/2020 07:13:00 AM            County             CASHELL RD
# 13      04/18/2020 03:58:00 PM  Maryland (State)  OLNEY LAYTONSVILLE RD
# ...                        ...               ...                    ...
# 157832        04-03-2023 10:00            County          CENTERHILL ST
# 157834        04-06-2023 18:19  Maryland (State)       W MONTGOMERY AVE
# 157835        04-06-2023 16:24  Maryland (State)             CLOPPER RD
# 157836        04-08-2023 05:10            County         SHADY GROVE RD
# 157837        04-08-2023 11:50  Maryland (State)            GEORGIA AVE
#
#        Cross-Street Type      Cross-Street Name            Collision Type  \
# 3                 County             ARCTIC AVE                     OTHER
# 4                 County      GUNNERS BRANCH RD                     OTHER
# 6           Municipality        TOWER OAKS BLVD         SAME DIR REAR END
# 7                 County         MUSIC GROVE CT            SINGLE VEHICLE
# 13                County        GOLF ESTATES DR  SAME DIRECTION SIDESWIPE
# ...                  ...                    ...                       ...
# 157832  Maryland (State)          VEIRS MILL RD   STRAIGHT MOVEMENT ANGLE
# 157834      Municipality              THOMAS ST         SAME DIR REAR END
# 157835            County            CINNAMON DR    ANGLE MEETS RIGHT TURN
# 157836  Maryland (State)      MUNCASTER MILL RD   STRAIGHT MOVEMENT ANGLE
# 157837  Maryland (State)  OLNEY SANDY SPRING RD         SAME DIR REAR END
#
#         Weather  ... Speed Limit Driverless Vehicle Parked Vehicle  \
# 3         CLEAR  ...          25                 No             No
# 4        CLOUDY  ...          25                 No             No
# 6         CLEAR  ...          40                 No             No
# 7        CLOUDY  ...          35                 No             No
# 13        CLEAR  ...          30                 No             No
# ...         ...  ...         ...                ...            ...
# 157832    CLEAR  ...          40                 No             No
# 157834  RAINING  ...          30                 No             No
# 157835    CLEAR  ...          30                 No             No
# 157836    CLEAR  ...          40                 No             No
# 157837    CLEAR  ...          30                 No             No
#
#        Vehicle Year Vehicle Make  Vehicle Model Equipment Problems   Latitude  \
# 3              2004        DODGE  GRAND CARAVAN          NO MISUSE  39.080062
# 4              2006        HONDA           CR-V            UNKNOWN  39.175230
# 6              2018         TOYT             4S          NO MISUSE  39.066925
# 7              2017         FORD       EXPLORER          NO MISUSE  39.131327
# 13             1998         MERZ             4S          NO MISUSE  39.201237
# ...             ...          ...            ...                ...        ...
# 157832         2022   VOLKSWAGEN           ID.4          NO MISUSE  39.050573
# 157834         2010       TOYOTA             4S          NO MISUSE  39.084660
# 157835         2008         TOYT          CAMRY          NO MISUSE  39.156162
# 157836         2019        HONDA          CIVIC          NO MISUSE  39.148709
# 157837         2020    CHEVROLET        EQUINOX          NO MISUSE  39.152575
#
#         Longitude                     Location
# 3      -77.097845    (39.08006167, -77.097845)
# 4      -77.241090        (39.17523, -77.24109)
# 6      -77.154085      (39.066925, -77.154085)
# 7      -77.083237  (39.13132667, -77.08323667)
# 13     -77.136003  (39.20123667, -77.13600333)
# ...           ...                          ...
# 157832 -77.072500  (39.05057264, -77.07250048)
# 157834 -77.161154  (39.08465969, -77.16115427)
# 157835 -77.264571  (39.15616222, -77.26457057)
# 157836 -77.147145  (39.14870889, -77.14714516)
# 157837 -77.066550       (39.152575, -77.06655)
#
# [77227 rows x 37 columns]

# %%
dropna_df.shape
# Out:
# (77227, 37)

# %%
dropna_df.isnull().sum()
# Out:
# Local Case Number                 0
# Agency Name                       0
# ACRS Report Type                  0
# Crash Date/Time                   0
# Route Type                        0
# Road Name                         0
# Cross-Street Type                 0
# Cross-Street Name                 0
# Collision Type                    0
# Weather                           0
# Surface Condition                 0
# Light                             0
# Traffic Control                   0
# Driver Substance Abuse            0
# Person ID                         0
# Driver At Fault                   0
# Injury Severity                   0
# Driver Distracted By              0
# Drivers License State             0
# Vehicle ID                        0
# Vehicle Damage Extent             0
# Vehicle First Impact Location     0
# Vehicle Second Impact Location    0
# Vehicle Body Type                 0
# Vehicle Movement                  0
# Vehicle Continuing Dir            0
# Vehicle Going Dir                 0
# Speed Limit                       0
# Driverless Vehicle                0
# Parked Vehicle                    0
# Vehicle Year                      0
# Vehicle Make                      0
# Vehicle Model                     0
# Equipment Problems                0
# Latitude                          0
# Longitude                         0
# Location                          0
# dtype: int64
